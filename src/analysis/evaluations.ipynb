# %%
import numpy as np

file_name = '../sessions/session_66a9d/evaluations.npz'

evals = np.load(file_name)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(evals['timesteps'], evals['results'])
plt.xlabel('Timesteps')
plt.ylabel('Rewards')
plt.title('Rewards vs Timesteps')
# Out:
# Text(0.5, 1.0, 'Rewards vs Timesteps')
